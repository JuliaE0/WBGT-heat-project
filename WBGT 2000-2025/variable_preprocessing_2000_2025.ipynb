# %% [markdown]
# # Variable Preprocessing 2000-2025

# %%
# install required libraries
# !pip install xarray netCDF4 h5netcdf numpy rioxarray regionmask geopandas "cdsapi>=0.7.7"

# %%
import xarray as xr
import numpy as np
import geopandas as gpd
import regionmask
import cdsapi
from pathlib import Path

# %% [markdown]
# ### Download ERA5-Land data

# %%
# use CDS API to download ERA5-Land data, loop over all months from 2000 to 2025

out_dir = Path("era5_land_data")
out_dir.mkdir(parents=True, exist_ok=True)
client = cdsapi.Client()
dataset = "reanalysis-era5-land"
request = {
    "variable": [
        "2m_dewpoint_temperature",
        "2m_temperature",
        "surface_solar_radiation_downwards",
        "10m_u_component_of_wind",
        "10m_v_component_of_wind",
        "surface_pressure"],
    "day": [f"{d:02d}" for d in range(1, 32)],
    "time": [f"{h:02d}:00" for h in range(0, 24)],
    "data_format": "netcdf",
    "download_format": "unarchived",
    "area": [42, -124.5, 32.5, -114.1]}

for y in range(2000, 2026):
    for m in range(1, 13):
        year = f"{y}"
        month = f"{m:02d}"
        target = out_dir/f"era5_land_{year}_{month}.nc"
        if target.exists():
            print("Skip existing:", target)
            continue
        req = request
        req["year"] = year
        req["month"] = month
        print("Downloading", target)
        client.retrieve(dataset, req, target)
# Out:
# Skip existing: era5_land_data\era5_land_2000_01.nc
# Skip existing: era5_land_data\era5_land_2000_02.nc
# Skip existing: era5_land_data\era5_land_2000_03.nc
# Skip existing: era5_land_data\era5_land_2000_04.nc
# Skip existing: era5_land_data\era5_land_2000_05.nc
# Downloading era5_land_data\era5_land_2000_06.nc
# 2026-02-19 11:30:04,598 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 11:30:04,599 INFO Request ID is a1423679-5ca7-4db2-ad7c-4f9c78d61ce4
# 2026-02-19 11:30:04,809 INFO status has been updated to accepted
# 2026-02-19 11:30:19,342 INFO status has been updated to running
# 2026-02-19 11:30:27,143 INFO status has been updated to successful
# c2da5f9c23942433513ae235e1c4e819.nc:   0%|          | 0.00/60.8M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2000_07.nc
# 2026-02-19 11:30:41,996 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 11:30:41,996 INFO Request ID is d24f0fe1-e7bf-487b-91ed-dc325f33290e
# 2026-02-19 11:30:42,189 INFO status has been updated to accepted
# 2026-02-19 11:30:56,412 INFO status has been updated to running
# 2026-02-19 11:39:08,638 INFO status has been updated to successful
# 51ec5dbfabdfd125ce358f9489eaa292.nc:   0%|          | 0.00/65.6M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2000_08.nc
# 2026-02-19 11:40:51,063 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 11:40:51,063 INFO Request ID is c9daca41-9b2b-49c1-bdbd-ffb46a5dc2b6
# 2026-02-19 11:40:51,274 INFO status has been updated to accepted
# 2026-02-19 11:41:00,357 INFO status has been updated to running
# 2026-02-19 11:49:18,516 INFO status has been updated to successful
# c6e099d17f11de0c01aa19ae5dca565a.nc:   0%|          | 0.00/64.0M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2000_09.nc
# 2026-02-19 11:49:37,397 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 11:49:37,397 INFO Request ID is 0fe8c4b2-54aa-467c-b060-4ac18c640445
# 2026-02-19 11:49:37,655 INFO status has been updated to accepted
# 2026-02-19 11:50:11,652 INFO status has been updated to running
# 2026-02-19 11:58:04,937 INFO status has been updated to successful
# df338074fb5e3ce637628c3cd125e6cf.nc:   0%|          | 0.00/59.6M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2000_10.nc
# 2026-02-19 11:58:17,983 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 11:58:17,983 INFO Request ID is 88b94fee-f733-46a8-88a4-6db0e61f049e
# 2026-02-19 11:58:18,248 INFO status has been updated to accepted
# 2026-02-19 11:58:40,571 INFO status has been updated to running
# 2026-02-19 12:06:47,257 INFO status has been updated to successful
# 2c41c42c2baea41f6bf9101bfd583ddb.nc:   0%|          | 0.00/63.6M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2000_11.nc
# 2026-02-19 12:07:09,841 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 12:07:09,843 INFO Request ID is c1e7eafe-ff58-4468-b9c9-2e473173ee87
# 2026-02-19 12:07:10,102 INFO status has been updated to accepted
# 2026-02-19 12:07:32,634 INFO status has been updated to running
# 2026-02-19 12:15:37,813 INFO status has been updated to successful
# 1037d141453df93c7c6aa65e8a62e0f6.nc:   0%|          | 0.00/58.6M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2000_12.nc
# 2026-02-19 12:15:57,608 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 12:15:57,608 INFO Request ID is ce10b274-5443-430c-9375-2d3d3ce154a8
# 2026-02-19 12:15:57,861 INFO status has been updated to accepted
# 2026-02-19 12:16:20,185 INFO status has been updated to running
# 2026-02-19 12:24:25,233 INFO status has been updated to successful
# 359acc3b92b973087f834b425c1ec49.nc:   0%|          | 0.00/62.3M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_01.nc
# 2026-02-19 12:24:39,204 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 12:24:39,204 INFO Request ID is ab06892d-cff7-40a5-b41b-f340eb821eff
# 2026-02-19 12:24:39,471 INFO status has been updated to accepted
# 2026-02-19 12:24:53,917 INFO status has been updated to running
# 2026-02-19 12:33:06,764 INFO status has been updated to successful
# a3e7e188a43d65de574f13d4b2912a14.nc:   0%|          | 0.00/62.9M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_02.nc
# 2026-02-19 12:33:29,181 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 12:33:29,185 INFO Request ID is bb536f78-718d-4a05-822f-100514837e11
# 2026-02-19 12:33:29,791 INFO status has been updated to accepted
# 2026-02-19 12:33:44,246 INFO status has been updated to running
# 2026-02-19 12:41:56,778 INFO status has been updated to successful
# 7d244336dab25fe77d24ad9d9f43554c.nc:   0%|          | 0.00/59.8M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_03.nc
# 2026-02-19 12:42:12,574 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 12:42:12,588 INFO Request ID is d18df14b-b695-47d5-b7f2-68c9f21e08d8
# 2026-02-19 12:42:12,851 INFO status has been updated to accepted
# 2026-02-19 12:42:27,390 INFO status has been updated to running
# 2026-02-19 12:42:46,948 INFO status has been updated to accepted
# 2026-02-19 12:43:04,351 INFO status has been updated to running
# 2026-02-19 12:50:40,542 INFO status has been updated to successful
# b481aad03b16d898acff4a9cbc795813.nc:   0%|          | 0.00/63.8M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_04.nc
# 2026-02-19 12:50:52,880 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 12:50:52,887 INFO Request ID is 19184b9e-9262-4bbb-bb09-68329b57b6bd
# 2026-02-19 12:50:53,132 INFO status has been updated to accepted
# 2026-02-19 12:51:27,090 INFO status has been updated to running
# 2026-02-19 12:59:20,244 INFO status has been updated to successful
# e72bc2e3ff600248b340b902aa288707.nc:   0%|          | 0.00/60.4M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_05.nc
# 2026-02-19 12:59:34,364 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 12:59:34,364 INFO Request ID is 3936f514-4830-47c6-bc9d-4393662651f3
# 2026-02-19 12:59:34,576 INFO status has been updated to accepted
# 2026-02-19 12:59:45,503 INFO status has been updated to running
# 2026-02-19 13:08:08,060 INFO status has been updated to successful
# fe02258cf077eec1e771ef0b1364dec1.nc:   0%|          | 0.00/64.3M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_06.nc
# 2026-02-19 13:08:29,469 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 13:08:29,472 INFO Request ID is 47fcd8ac-06af-4022-9e10-6e1323a4a2af
# 2026-02-19 13:08:29,981 INFO status has been updated to accepted
# 2026-02-19 13:08:39,094 INFO status has been updated to running
# 2026-02-19 13:16:58,301 INFO status has been updated to successful
# c3859c69c85e10e0a5877dc2f7046206.nc:   0%|          | 0.00/60.7M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_07.nc
# 2026-02-19 13:17:16,437 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 13:17:16,440 INFO Request ID is cb940de6-ab9c-4f04-a801-be39397ab5c0
# 2026-02-19 13:17:16,715 INFO status has been updated to accepted
# 2026-02-19 13:17:39,143 INFO status has been updated to running
# 2026-02-19 13:25:44,203 INFO status has been updated to successful
# 10aa8c5c522e825ec955a4b77be2b328.nc:   0%|          | 0.00/64.8M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_08.nc
# 2026-02-19 13:27:26,650 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 13:27:26,650 INFO Request ID is 3ff727d7-5210-4cbe-a3a1-39595cdcb94b
# 2026-02-19 13:27:26,870 INFO status has been updated to accepted
# 2026-02-19 13:27:35,913 INFO status has been updated to running
# 2026-02-19 13:37:56,181 INFO status has been updated to successful
# bee65139bbca0e37e55e9e6ae6f17f49.nc:   0%|          | 0.00/64.6M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_09.nc
# 2026-02-19 13:38:14,433 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 13:38:14,433 INFO Request ID is eebd8702-eaba-4d0b-87ea-09f71e93520d
# 2026-02-19 13:38:14,675 INFO status has been updated to accepted
# 2026-02-19 13:38:23,695 INFO status has been updated to running
# 2026-02-19 13:56:29,718 INFO status has been updated to successful
# 740a34a3a02294669c5fe1803a5f240e.nc:   0%|          | 0.00/59.7M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_10.nc
# 2026-02-19 13:56:42,381 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 13:56:42,381 INFO Request ID is a1d1b62d-4c67-48fa-bc02-ff1003f38d0d
# 2026-02-19 13:56:42,627 INFO status has been updated to accepted
# 2026-02-19 13:56:56,907 INFO status has been updated to running
# 2026-02-19 14:05:20,882 INFO status has been updated to successful
# 90eee79837c2a4e63a3d09d2bc421eff.nc:   0%|          | 0.00/61.9M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_11.nc
# 2026-02-19 14:05:39,395 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 14:05:39,399 INFO Request ID is 6c0ffef5-2e57-4be9-ab1e-3e8147791316
# 2026-02-19 14:05:39,618 INFO status has been updated to accepted
# 2026-02-19 14:05:54,242 INFO status has been updated to running
# 2026-02-19 14:14:12,411 INFO status has been updated to successful
# 399d3dc042d5bb384084b0628bc52eef.nc:   0%|          | 0.00/58.1M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2001_12.nc
# 2026-02-19 14:14:31,191 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 14:14:31,195 INFO Request ID is 45dce6d1-7049-4e43-886c-d1ee6766726d
# 2026-02-19 14:14:31,461 INFO status has been updated to accepted
# 2026-02-19 14:14:45,999 INFO status has been updated to running
# 2026-02-19 14:25:08,452 INFO status has been updated to successful
# fbe829201343ec71763f37dcabc8345f.nc:   0%|          | 0.00/62.2M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_01.nc
# 2026-02-19 14:25:41,159 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 14:25:41,159 INFO Request ID is 5b3ba2cf-5747-4d51-aea1-3b632cd96e9b
# 2026-02-19 14:25:41,445 INFO status has been updated to accepted
# 2026-02-19 14:25:55,973 INFO status has been updated to running
# 2026-02-19 14:34:08,719 INFO status has been updated to successful
# b9bda17b3b5715fdffac905ccef11ed1.nc:   0%|          | 0.00/62.5M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_02.nc
# 2026-02-19 14:34:22,037 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 14:34:22,037 INFO Request ID is f9105776-2765-4397-8693-a135b19dc6f5
# 2026-02-19 14:34:22,256 INFO status has been updated to accepted
# 2026-02-19 14:34:36,735 INFO status has been updated to running
# 2026-02-19 14:42:49,725 INFO status has been updated to successful
# 6e1718cd86fa3ff5772c7864a8ed9f3d.nc:   0%|          | 0.00/57.5M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_03.nc
# 2026-02-19 14:43:11,565 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 14:43:11,566 INFO Request ID is 6a2cd0e2-7ff1-42dd-9cf5-cf3fd4913dbb
# 2026-02-19 14:43:11,781 INFO status has been updated to accepted
# 2026-02-19 14:43:26,384 INFO status has been updated to running
# 2026-02-19 14:51:38,947 INFO status has been updated to successful
# 90d5353c078bde771a740f28c1b0912c.nc:   0%|          | 0.00/63.8M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_04.nc
# 2026-02-19 14:51:52,579 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 14:51:52,582 INFO Request ID is d7dd237b-9516-4c38-8355-e756620109db
# 2026-02-19 14:51:52,790 INFO status has been updated to accepted
# 2026-02-19 14:52:15,072 INFO status has been updated to running
# 2026-02-19 15:00:19,816 INFO status has been updated to successful
# ca70d1f2ecbbf36552343164663ec71e.nc:   0%|          | 0.00/60.3M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_05.nc
# 2026-02-19 15:00:40,030 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 15:00:40,030 INFO Request ID is 91f6509b-d36c-414a-832a-499854d186b3
# 2026-02-19 15:00:40,295 INFO status has been updated to accepted
# 2026-02-19 15:01:02,611 INFO status has been updated to running
# 2026-02-19 15:09:07,594 INFO status has been updated to successful
# 6469a7c451c0669bf4a78e3180cbf81e.nc:   0%|          | 0.00/64.0M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_06.nc
# 2026-02-19 15:09:25,344 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 15:09:25,344 INFO Request ID is b984ffa6-29b2-4d7f-9277-7cf3a7dab301
# 2026-02-19 15:09:25,597 INFO status has been updated to accepted
# 2026-02-19 15:09:40,134 INFO status has been updated to running
# 2026-02-19 15:17:52,673 INFO status has been updated to successful
# 6ac9231c6c84cc6e76fefbc537b6dc2c.nc:   0%|          | 0.00/61.2M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_07.nc
# 2026-02-19 15:18:10,546 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 15:18:10,548 INFO Request ID is 3671c6d7-628c-42fe-ac78-4b3e6ff5236f
# 2026-02-19 15:18:10,793 INFO status has been updated to accepted
# 2026-02-19 15:18:20,013 INFO status has been updated to running
# 2026-02-19 15:26:37,977 INFO status has been updated to successful
# 7a1c9d175a5e04b25d74332af8e2c339.nc:   0%|          | 0.00/64.4M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_08.nc
# 2026-02-19 15:27:44,933 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 15:27:44,947 INFO Request ID is 91bfbc82-a612-43e7-9363-14e8da30ae65
# 2026-02-19 15:27:45,177 INFO status has been updated to accepted
# 2026-02-19 15:27:54,302 INFO status has been updated to running
# 2026-02-19 15:36:12,533 INFO status has been updated to successful
# 4171a3944e28bf8f6967062f22cc6d06.nc:   0%|          | 0.00/64.4M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_09.nc
# 2026-02-19 15:36:30,580 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 15:36:30,582 INFO Request ID is 1268c326-4116-4415-a912-d78e61d742a0
# 2026-02-19 15:36:30,862 INFO status has been updated to accepted
# 2026-02-19 15:36:40,173 INFO status has been updated to running
# 2026-02-19 15:44:58,457 INFO status has been updated to successful
# c3dfae5f42cfaccb9376a020570692a0.nc:   0%|          | 0.00/59.8M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_10.nc
# 2026-02-19 15:45:16,061 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 15:45:16,063 INFO Request ID is 16bf86ed-f14c-4173-bdcd-40309c787a40
# 2026-02-19 15:45:16,370 INFO status has been updated to accepted
# 2026-02-19 15:45:50,468 INFO status has been updated to running
# 2026-02-19 15:53:42,670 INFO status has been updated to successful
# e70a1b370b0fad4884f09faa166d522a.nc:   0%|          | 0.00/62.5M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_11.nc
# 2026-02-19 15:53:56,978 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 15:53:56,980 INFO Request ID is 18106311-e083-4ccd-8a89-f06ef86de6a6
# 2026-02-19 15:53:57,294 INFO status has been updated to accepted
# 2026-02-19 15:54:11,539 INFO status has been updated to running
# 2026-02-19 15:54:19,329 INFO status has been updated to accepted
# 2026-02-19 15:54:30,920 INFO status has been updated to running
# 2026-02-19 16:02:21,594 INFO status has been updated to successful
# 3ae013425c25b7e0046f9a6c5516c7fc.nc:   0%|          | 0.00/58.8M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2002_12.nc
# 2026-02-19 16:02:32,994 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 16:02:32,995 INFO Request ID is 6a106ccc-85ef-4a84-8285-d01106a74aff
# 2026-02-19 16:02:33,192 INFO status has been updated to accepted
# 2026-02-19 16:02:47,410 INFO status has been updated to running
# 2026-02-19 16:10:57,333 INFO status has been updated to successful
# e7b6b7ece284ef0bd507bb43f0409100.nc:   0%|          | 0.00/62.0M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_01.nc
# 2026-02-19 16:11:10,694 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 16:11:10,710 INFO Request ID is a5c3e908-bd63-4cf3-8c81-455f4dc94805
# 2026-02-19 16:11:10,924 INFO status has been updated to accepted
# 2026-02-19 16:11:25,147 INFO status has been updated to running
# 2026-02-19 16:19:35,088 INFO status has been updated to successful
# ea1d638277c7e09fd5ff97ae68a0bcc6.nc:   0%|          | 0.00/62.4M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_02.nc
# 2026-02-19 16:19:45,624 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 16:19:45,624 INFO Request ID is dedb472a-caa0-4546-9892-4e47a9d8dc98
# 2026-02-19 16:19:45,847 INFO status has been updated to accepted
# 2026-02-19 16:21:02,591 INFO status has been updated to running
# 2026-02-19 16:30:11,277 INFO status has been updated to successful
# c53f04450c0e4f0f51c33a88126e9665.nc:   0%|          | 0.00/58.6M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_03.nc
# 2026-02-19 16:30:26,900 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 16:30:26,902 INFO Request ID is 4f99bcf0-9183-402c-ae1a-92a41ebf22ed
# 2026-02-19 16:30:27,125 INFO status has been updated to accepted
# 2026-02-19 16:30:41,329 INFO status has been updated to running
# 2026-02-19 16:38:51,785 INFO status has been updated to successful
# 3ddf9451c7dea82975307e16ecd755f1.nc:   0%|          | 0.00/63.6M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_04.nc
# 2026-02-19 16:39:05,277 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 16:39:05,277 INFO Request ID is 861ad13a-e8d9-4a16-8f18-862793cb2fcc
# 2026-02-19 16:39:05,467 INFO status has been updated to accepted
# 2026-02-19 16:39:19,658 INFO status has been updated to running
# 2026-02-19 16:47:29,466 INFO status has been updated to successful
# 6edf1f76e39c307902f633dc276e346e.nc:   0%|          | 0.00/60.4M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_05.nc
# 2026-02-19 16:47:45,384 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 16:47:45,385 INFO Request ID is 2a3e896d-29a1-49a4-9776-90721ad4b6d8
# 2026-02-19 16:47:45,610 INFO status has been updated to accepted
# 2026-02-19 16:47:59,841 INFO status has been updated to running
# 2026-02-19 16:56:10,063 INFO status has been updated to successful
# 34a7e9181f4df9b67443c462c275c5c2.nc:   0%|          | 0.00/64.0M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_06.nc
# 2026-02-19 16:56:23,522 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 16:56:23,537 INFO Request ID is f81eb067-5b1c-49c2-9095-d31248490393
# 2026-02-19 16:56:23,729 INFO status has been updated to accepted
# 2026-02-19 16:56:37,916 INFO status has been updated to running
# 2026-02-19 17:04:47,946 INFO status has been updated to successful
# 9274e9522937bb6919666a8b9a21efc7.nc:   0%|          | 0.00/61.0M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_07.nc
# 2026-02-19 17:05:05,610 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 17:05:05,612 INFO Request ID is a8de2f34-dcb6-4fa0-ba05-df5eefed8cbc
# 2026-02-19 17:05:05,834 INFO status has been updated to accepted
# 2026-02-19 17:05:27,977 INFO status has been updated to running
# 2026-02-19 17:13:32,694 INFO status has been updated to successful
# e53bfca956dd3949dd73f4a1f5953bf2.nc:   0%|          | 0.00/65.1M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_08.nc
# 2026-02-19 17:13:48,667 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 17:13:48,667 INFO Request ID is 999f11b0-95f8-4f2e-b638-ef7f07aaa77f
# 2026-02-19 17:13:48,971 INFO status has been updated to accepted
# 2026-02-19 17:14:22,973 INFO status has been updated to running
# 2026-02-19 17:30:20,199 INFO status has been updated to successful
# 65edb9dfcf3da72b33d2dba4651d945d.nc:   0%|          | 0.00/63.9M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_09.nc
# 2026-02-19 17:30:33,782 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 17:30:33,782 INFO Request ID is fab8df19-1687-40c7-aae3-30faedda2a4e
# 2026-02-19 17:30:34,005 INFO status has been updated to accepted
# 2026-02-19 17:30:48,615 INFO status has been updated to running
# 2026-02-19 17:39:01,709 INFO status has been updated to successful
# ed44b714b0c27bc514bd99f9469fed81.nc:   0%|          | 0.00/59.6M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_10.nc
# 2026-02-19 17:39:16,588 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 17:39:16,593 INFO Request ID is eadaf9e1-40a3-418d-83cd-579f5c566032
# 2026-02-19 17:39:17,169 INFO status has been updated to accepted
# 2026-02-19 17:39:51,370 INFO status has been updated to running
# 2026-02-19 18:18:01,414 INFO status has been updated to successful
# ec6fb5d9b41206b9d0ff8eacb85e23c5.nc:   0%|          | 0.00/62.7M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_11.nc
# 2026-02-19 18:18:16,261 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 18:18:16,264 INFO Request ID is 82e5a513-2c2d-49c2-9140-6ef73612beb8
# 2026-02-19 18:18:16,568 INFO status has been updated to accepted
# 2026-02-19 18:18:50,357 INFO status has been updated to running
# 2026-02-19 18:26:43,644 INFO status has been updated to successful
# 76fd75d3fa2234fa667317b6eaa5c633.nc:   0%|          | 0.00/58.9M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2003_12.nc
# 2026-02-19 18:26:56,951 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 18:26:56,951 INFO Request ID is 83e2d3ca-da9a-4e48-834f-d9ad94ffa307
# 2026-02-19 18:26:57,165 INFO status has been updated to accepted
# 2026-02-19 18:27:06,376 INFO status has been updated to running
# 2026-02-19 18:47:51,828 INFO status has been updated to successful
# 5a436f4da81e8362864746c3925fbb7d.nc:   0%|          | 0.00/62.0M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2004_01.nc
# 2026-02-19 18:48:06,288 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 18:48:06,290 INFO Request ID is 2fde1824-7943-4366-a537-4db35557c102
# 2026-02-19 18:48:06,495 INFO status has been updated to accepted
# 2026-02-19 18:48:20,828 INFO status has been updated to running
# 2026-02-19 18:56:34,188 INFO status has been updated to successful
# 88e3654691255886b0719e250f7a366d.nc:   0%|          | 0.00/62.5M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2004_02.nc
# 2026-02-19 18:56:53,272 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-19 18:56:53,272 INFO Request ID is b9a4a862-513f-44cf-9874-a2878a996290
# 2026-02-19 18:56:53,532 INFO status has been updated to accepted
# 2026-02-19 18:57:08,119 INFO status has been updated to running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 33
#      31 req["month"] = month
#      32 print("Downloading", target)
# ---> 33 client.retrieve(dataset, req, target)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\legacy_client.py:167, in LegacyClient.retrieve(self, name, request, target)
#     165 submitted: datastores.Remote | datastores.Results
#     166 if self.wait_until_complete:
# --> 167     submitted = self.client.submit_and_wait_on_results(
#     168         collection_id=name,
#     169         request=request,
#     170     )
#     171 else:
#     172     submitted = self.client.submit(
#     173         collection_id=name,
#     174         request=request,
#     175     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\client.py:414, in Client.submit_and_wait_on_results(self, collection_id, request)
#     398 def submit_and_wait_on_results(
#     399     self, collection_id: str, request: dict[str, Any]
#     400 ) -> datastores.Results:
#     401     """Submit a request and wait for the results to be ready.
#     402
#     403     Parameters
#    (...)    412     datastores.Results
#     413     """
# --> 414     return self._retrieve_api.submit(collection_id, request).get_results()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\processing.py:495, in Remote.get_results(self)
#     488 def get_results(self) -> Results:
#     489     """Retrieve results.
#     490
#     491     Returns
#     492     -------
#     493     datastores.Results
#     494     """
# --> 495     return self._make_results(wait=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\processing.py:479, in Remote._make_results(self, wait)
#     477 def _make_results(self, wait: bool) -> Results:
#     478     if wait:
# --> 479         self._wait_on_results()
#     480     response = self._get_api_response("get")
#     481     try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\processing.py:459, in Remote._wait_on_results(self)
#     457 while not self.results_ready:
#     458     self.debug(f"results not ready, waiting for {sleep} seconds")
# --> 459     time.sleep(sleep)
#     460     sleep = min(sleep * 1.5, self.sleep_max)
#
# KeyboardInterrupt:

# %%
# join the downloaded ERA5-Land files
# era5land = xr.open_dataset('name_of_joined_file.nc') # open ERA5-Land NetCDF file
# print(era5land) # view structure

# %% [markdown]
# ### Download ERA5 data

# %%
# use CDS API to download ERA5 data
