# %% [markdown]
# # Variable Preprocessing 2000-2025

# %%
# install required libraries
# !pip install xarray netCDF4 h5netcdf numpy rioxarray regionmask geopandas "cdsapi>=0.7.7"

# %%
import xarray as xr
import numpy as np
import geopandas as gpd
import regionmask
import cdsapi
from pathlib import Path

# %% [markdown]
# ### Download ERA5-Land data

# %%
# use CDS API to download ERA5-Land data, loop over all months from 2000 to 2025

out_dir = Path("era5_land_data")
out_dir.mkdir(parents=True, exist_ok=True)
client = cdsapi.Client()
dataset = "reanalysis-era5-land"
request = {
    "variable": [
        "2m_dewpoint_temperature",
        "2m_temperature",
        "surface_solar_radiation_downwards",
        "10m_u_component_of_wind",
        "10m_v_component_of_wind",
        "surface_pressure"],
    "day": [f"{d:02d}" for d in range(1, 32)],
    "time": [f"{h:02d}:00" for h in range(0, 24)],
    "data_format": "netcdf",
    "download_format": "unarchived",
    "area": [42, -124.5, 32.5, -114.1]}

for y in range(2000, 2026):
    for m in range(1, 13):
        year = f"{y}"
        month = f"{m:02d}"
        target = out_dir/f"era5_land_{year}_{month}.nc"
        if target.exists():
            print("Skip existing:", target)
            continue
        req = request
        req["year"] = year
        req["month"] = month
        print("Downloading", target)
        client.retrieve(dataset, req, target)
# Out:
# Skip existing: era5_land_data\era5_land_2000_01.nc
# Skip existing: era5_land_data\era5_land_2000_02.nc
# Skip existing: era5_land_data\era5_land_2000_03.nc
# Skip existing: era5_land_data\era5_land_2000_04.nc
# Skip existing: era5_land_data\era5_land_2000_05.nc
# Skip existing: era5_land_data\era5_land_2000_06.nc
# Skip existing: era5_land_data\era5_land_2000_07.nc
# Skip existing: era5_land_data\era5_land_2000_08.nc
# Skip existing: era5_land_data\era5_land_2000_09.nc
# Skip existing: era5_land_data\era5_land_2000_10.nc
# Skip existing: era5_land_data\era5_land_2000_11.nc
# Skip existing: era5_land_data\era5_land_2000_12.nc
# Skip existing: era5_land_data\era5_land_2001_01.nc
# Skip existing: era5_land_data\era5_land_2001_02.nc
# Skip existing: era5_land_data\era5_land_2001_03.nc
# Skip existing: era5_land_data\era5_land_2001_04.nc
# Skip existing: era5_land_data\era5_land_2001_05.nc
# Skip existing: era5_land_data\era5_land_2001_06.nc
# Skip existing: era5_land_data\era5_land_2001_07.nc
# Skip existing: era5_land_data\era5_land_2001_08.nc
# Skip existing: era5_land_data\era5_land_2001_09.nc
# Skip existing: era5_land_data\era5_land_2001_10.nc
# Skip existing: era5_land_data\era5_land_2001_11.nc
# Skip existing: era5_land_data\era5_land_2001_12.nc
# Skip existing: era5_land_data\era5_land_2002_01.nc
# Skip existing: era5_land_data\era5_land_2002_02.nc
# Skip existing: era5_land_data\era5_land_2002_03.nc
# Skip existing: era5_land_data\era5_land_2002_04.nc
# Skip existing: era5_land_data\era5_land_2002_05.nc
# Skip existing: era5_land_data\era5_land_2002_06.nc
# Skip existing: era5_land_data\era5_land_2002_07.nc
# Skip existing: era5_land_data\era5_land_2002_08.nc
# Skip existing: era5_land_data\era5_land_2002_09.nc
# Skip existing: era5_land_data\era5_land_2002_10.nc
# Skip existing: era5_land_data\era5_land_2002_11.nc
# Skip existing: era5_land_data\era5_land_2002_12.nc
# Skip existing: era5_land_data\era5_land_2003_01.nc
# Skip existing: era5_land_data\era5_land_2003_02.nc
# Skip existing: era5_land_data\era5_land_2003_03.nc
# Skip existing: era5_land_data\era5_land_2003_04.nc
# Skip existing: era5_land_data\era5_land_2003_05.nc
# Skip existing: era5_land_data\era5_land_2003_06.nc
# Skip existing: era5_land_data\era5_land_2003_07.nc
# Skip existing: era5_land_data\era5_land_2003_08.nc
# Skip existing: era5_land_data\era5_land_2003_09.nc
# Skip existing: era5_land_data\era5_land_2003_10.nc
# Skip existing: era5_land_data\era5_land_2003_11.nc
# Skip existing: era5_land_data\era5_land_2003_12.nc
# Skip existing: era5_land_data\era5_land_2004_01.nc
# Downloading era5_land_data\era5_land_2004_02.nc
# 2026-02-20 15:00:29,783 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20 15:00:29,783 INFO Request ID is 0b1fdff9-17d7-4966-871a-5759dc084e4f
# 2026-02-20 15:00:30,035 INFO status has been updated to accepted
# 2026-02-20 15:00:39,771 INFO status has been updated to running
# 2026-02-20 15:00:45,054 INFO status has been updated to successful
# 1d415b4a00f9060cceab873c75388eb4.nc:   0%|          | 0.00/60.3M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2004_03.nc
# 2026-02-20 15:00:58,559 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20 15:00:58,559 INFO Request ID is 9042e96a-0d3d-424c-98e8-e2b8dc222693
# 2026-02-20 15:00:58,783 INFO status has been updated to accepted
# 2026-02-20 15:01:13,047 INFO status has been updated to running
# 2026-02-20 15:09:23,771 INFO status has been updated to successful
# a53f7eec1d38b43b34dd58543bb4adcb.nc:   0%|          | 0.00/63.1M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2004_04.nc
# 2026-02-20 15:09:37,277 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20 15:09:37,278 INFO Request ID is 8f595595-f471-4816-aee6-707aaae7f563
# 2026-02-20 15:09:37,516 INFO status has been updated to accepted
# 2026-02-20 15:09:51,707 INFO status has been updated to running
# 2026-02-20 15:18:01,679 INFO status has been updated to successful
# c674c114d9ee23aef1b31a6163e224dc.nc:   0%|          | 0.00/60.1M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2004_05.nc
# 2026-02-20 15:18:31,429 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20 15:18:31,431 INFO Request ID is 6fa7816a-642c-4317-853f-d09672d0834f
# 2026-02-20 15:18:31,638 INFO status has been updated to accepted
# 2026-02-20 15:18:45,849 INFO status has been updated to running
# 2026-02-20 15:26:56,009 INFO status has been updated to successful
# d9e130fcbef4d5b43a06eca12ebb4764.nc:   0%|          | 0.00/64.0M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2004_06.nc
# 2026-02-20 15:27:15,031 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20 15:27:15,032 INFO Request ID is 081bcb4f-2304-4596-ad8f-177a01a7896c
# 2026-02-20 15:27:15,255 INFO status has been updated to accepted
# 2026-02-20 15:27:24,220 INFO status has been updated to running
# 2026-02-20 15:27:49,054 INFO status has been updated to accepted
# 2026-02-20 15:28:06,361 INFO status has been updated to running
# 2026-02-20 15:35:39,809 INFO status has been updated to successful
# 9f5402c549fd332692263f2416504518.nc:   0%|          | 0.00/61.1M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2004_07.nc
# 2026-02-20 15:35:58,792 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20
INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20 22:22:53,744 INFO Request ID is ab5560af-2b70-4afd-a9c7-1cc9cf1fb8c2
# 2026-02-20 22:22:54,059 INFO status has been updated to accepted
# 2026-02-20 22:23:08,498 INFO status has been updated to running
# 2026-02-20 22:31:20,860 INFO status has been updated to successful
# 2b74dc441946a7dec076db0ccfd442ad.nc:   0%|          | 0.00/63.9M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2007_11.nc
# 2026-02-20 22:31:33,742 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20 22:31:33,745 INFO Request ID is 581c6854-734a-4a3d-97e4-c0491586c2d5
# 2026-02-20 22:31:34,042 INFO status has been updated to accepted
# 2026-02-20 22:31:48,593 INFO status has been updated to running
# 2026-02-20 22:40:01,252 INFO status has been updated to successful
# 8843d55d4523bb7f35e48ee526800b45.nc:   0%|          | 0.00/58.1M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2007_12.nc
# 2026-02-20 22:40:23,151 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20 22:40:23,158 INFO Request ID is a68435cc-df6f-48cf-be09-4683c8a9cff9
# 2026-02-20 22:40:23,454 INFO status has been updated to accepted
# 2026-02-20 22:40:32,685 INFO status has been updated to running
# 2026-02-20 22:48:50,546 INFO status has been updated to successful
# 54fb20ec583b6f699e87e526e24a1471.nc:   0%|          | 0.00/62.6M [00:00<?, ?B/s]
# Downloading era5_land_data\era5_land_2008_01.nc
# 2026-02-20 22:49:32,464 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land-timeseries?tab=overview)
# 2026-02-20 22:49:32,469 INFO Request ID is dbd1c11b-8f96-42fb-9836-f1a0eda68c9a
# 2026-02-20 22:49:32,739 INFO status has been updated to accepted
# 2026-02-20 22:49:47,074 INFO status has been updated to running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 33
#      31 req["month"] = month
#      32 print("Downloading", target)
# ---> 33 client.retrieve(dataset, req, target)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\legacy_client.py:167, in LegacyClient.retrieve(self, name, request, target)
#     165 submitted: datastores.Remote | datastores.Results
#     166 if self.wait_until_complete:
# --> 167     submitted = self.client.submit_and_wait_on_results(
#     168         collection_id=name,
#     169         request=request,
#     170     )
#     171 else:
#     172     submitted = self.client.submit(
#     173         collection_id=name,
#     174         request=request,
#     175     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\client.py:414, in Client.submit_and_wait_on_results(self, collection_id, request)
#     398 def submit_and_wait_on_results(
#     399     self, collection_id: str, request: dict[str, Any]
#     400 ) -> datastores.Results:
#     401     """Submit a request and wait for the results to be ready.
#     402
#     403     Parameters
#    (...)    412     datastores.Results
#     413     """
# --> 414     return self._retrieve_api.submit(collection_id, request).get_results()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\processing.py:495, in Remote.get_results(self)
#     488 def get_results(self) -> Results:
#     489     """Retrieve results.
#     490
#     491     Returns
#     492     -------
#     493     datastores.Results
#     494     """
# --> 495     return self._make_results(wait=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\processing.py:479, in Remote._make_results(self, wait)
#     477 def _make_results(self, wait: bool) -> Results:
#     478     if wait:
# --> 479         self._wait_on_results()
#     480     response = self._get_api_response("get")
#     481     try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ecmwf\datastores\processing.py:459, in Remote._wait_on_results(self)
#     457 while not self.results_ready:
#     458     self.debug(f"results not ready, waiting for {sleep} seconds")
# --> 459     time.sleep(sleep)
#     460     sleep = min(sleep * 1.5, self.sleep_max)
#
# KeyboardInterrupt:

# %%
# join the downloaded ERA5-Land files?
# era5land = xr.open_dataset('name_of_joined_file.nc') # open ERA5-Land NetCDF file
# print(era5land) # view structure

# %% [markdown]
# ### Download ERA5 data

# %%
# use CDS API to download ERA5 data
